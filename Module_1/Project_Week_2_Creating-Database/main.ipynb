# %%
# your code here
import pandas as pd
#import matplotlib.pyplot as plt
import wbgapi as wb


print('****** Type',type(wb.source.info()))
print('source.info:',wb.source.info())
print('region.info',wb.region.info())
print('series.info',wb.series.info())
print('economy.info', wb.economy.info())

print('series.info(q="healthcare")',wb.series.info(q='healthcare'))

wb.data.DataFrame('IC.REG.DURS', ['FRA','UKR','EST'], time=range(2000,2019,3)).T.plot();
# Out:
# ****** Type <class 'wbgapi.Featureset'>
# source.info: id    name                                                                  code      concepts  lastupdated
# ----  --------------------------------------------------------------------  ------  ----------  -------------
# 1     Doing Business                                                        DBS              3  2021-08-18
# 2     World Development Indicators                                          WDI              3  2023-03-30
# 3     Worldwide Governance Indicators                                       WGI              3  2022-09-23
# 5     Subnational Malnutrition Database                                     SNM              3  2016-03-21
# 6     International Debt Statistics                                         IDS              4  2022-12-06
# 11    Africa Development Indicators                                         ADI              3  2013-02-22
# ...
